# %%
##1. Write a python program to display all the header tags from 
##‘en.wikipedia.org/wiki/Main_Page
# Out:
# C:\Python 2\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("http://en.wikipedia.org/wiki/Main_Page")
page.content
soup=BeautifulSoup(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
tags=soup.find_all(["h1","h2","h3"])
tags
# Out:
# [<h1 class="firstHeading" id="firstHeading">Main Page</h1>,
#  <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>,
#  <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>,
#  <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>,
#  <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>,
#  <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>,
#  <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>,
# ...

# %%
tags_all=[]
for i in tags:
    tags_all.append(i.text.replace("\n",""))
tags_all
# Out:
# ['Main Page',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages',
#  'Navigation menu',
#  'Personal tools',
#  'Namespaces',
#  'Variants',
#  'Views',
#  'More',
#  'Search',
#  'Navigation',
#  'Contribute',
#  'Tools',
#  'Print/export',
#  'In other projects',
#  'Languages']

# %%
import pandas as pd
taglist=pd.DataFrame({})
taglist["Headertag"]=tags_all
print(taglist)
# Out:
#                         Headertag
# 0                       Main Page
# 1   From today's featured article
# 2                Did you know ...
# 3                     In the news
# 4                     On this day
# 5        Today's featured picture
# 6        Other areas of Wikipedia
# 7     Wikipedia's sister projects
# 8             Wikipedia languages
# 9                 Navigation menu
# 10                 Personal tools
# 11                     Namespaces
# 12                       Variants
# 13                          Views
# 14                           More
# 15                         Search
# 16                     Navigation
# 17                     Contribute
# 18                          Tools
# 19                   Print/export
# 20              In other projects
# 21                      Languages

# %%
taglist
# Out:
#                         Headertag
# 0                       Main Page
# 1   From today's featured article
# 2                Did you know ...
# 3                     In the news
# 4                     On this day
# 5        Today's featured picture
# 6        Other areas of Wikipedia
# 7     Wikipedia's sister projects
# 8             Wikipedia languages
# 9                 Navigation menu
# 10                 Personal tools
# 11                     Namespaces
# 12                       Variants
# 13                          Views
# 14                           More
# 15                         Search
# 16                     Navigation
# 17                     Contribute
# 18                          Tools
# 19                   Print/export
# 20              In other projects
# 21                      Languages

# %%
##Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, 
##IMDB rating, Year of release) and save it in form of a CSV file.

# %%
mov=requests.get("https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc")
mov.content
soup=BeautifulSoup(mov.content,'html.parser')
Name=soup.find_all("h3",class_="lister-item-header")
Name
# Out:
# [<h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt0111161/">The Shawshank Redemption</a>
#  <span class="lister-item-year text-muted unbold">(1994)</span>
#  </h3>, <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">2.</span>
#  <a href="/title/tt0068646/">The Godfather</a>
#  <span class="lister-item-year text-muted unbold">(1972)</span>
#  </h3>, <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">3.</span>
#  <a href="/title/tt0468569/">The Dark Knight</a>
#  <span class="lister-item-year text-muted unbold">(2008)</span>
#  </h3>, <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">4.</span>
#  <a href="/title/tt0071562/">The Godfather: Part II</a>
#  <span class="lister-item-year text-muted unbold">(1974)</span>
#  </h3>, <h3 class="lister-item-header">
# ...

# %%
movie_name=[]
for i in Name:
    movie_name.append(i.text.replace("\n",""))
movie_name
# Out:
# ['1.The Shawshank Redemption(1994)',
#  '2.The Godfather(1972)',
#  '3.The Dark Knight(2008)',
#  '4.The Godfather: Part II(1974)',
#  '5.12 Angry Men(1957)',
#  '6.The Lord of the Rings: The Return of the King(2003)',
#  '7.Pulp Fiction(1994)',
#  "8.Schindler's List(1993)",
#  '9.Inception(2010)',
#  '10.Fight Club(1999)',
#  '11.The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '12.Forrest Gump(1994)',
#  '13.Il buono, il brutto, il cattivo(1966)',
#  '14.The Lord of the Rings: The Two Towers(2002)',
#  '15.The Matrix(1999)',
#  '16.Goodfellas(1990)',
#  '17.Star Wars: Episode V - The Empire Strikes Back(1980)',
#  "18.One Flew Over the Cuckoo's Nest(1975)",
#  '19.Gisaengchung(2019)',
#  '20.Interstellar(2014)',
#  '21.Cidade de Deus(2002)',
#  '22.Sen to Chihiro no kamikakushi(2001)',
#  '23.Saving Private Ryan(1998)',
#  '24.The Green Mile(1999)',
#  '25.La vita è bella(1997)',
#  '26.Se7en(1995)',
#  '27.The Silence of the Lambs(1991)',
#  '28.Star Wars(1977)',
# ...

# %%
year=soup.find_all("span","lister-item-year text-muted unbold")
year
movie_year=[]
for i in year:
    movie_year.append(i.text.replace("\n",""))
movie_year
# Out:
# ['(1994)',
#  '(1972)',
#  '(2008)',
#  '(1974)',
#  '(1957)',
#  '(2003)',
#  '(1994)',
#  '(1993)',
#  '(2010)',
#  '(1999)',
#  '(2001)',
#  '(1994)',
#  '(1966)',
#  '(2002)',
#  '(1999)',
#  '(1990)',
#  '(1980)',
#  '(1975)',
#  '(2019)',
#  '(2014)',
#  '(2002)',
#  '(2001)',
#  '(1998)',
#  '(1999)',
#  '(1997)',
#  '(1995)',
#  '(1991)',
#  '(1977)',
#  '(1962)',
#  '(1954)',
#  '(1946)',
#  '(2020)',
#  '(2014)',
#  '(2011)',
#  '(2006)',
#  '(2006)',
#  '(2002)',
#  '(2000)',
#  '(1998)',
#  '(1995)',
#  '(1994)',
#  '(1994)',
#  '(1991)',
#  '(1988)',
#  '(1988)',
#  '(1985)',
#  '(1968)',
#  '(1960)',
#  '(1942)',
#  '(1936)']

# %%
rating=soup.find_all("div",class_="inline-block ratings-imdb-rating")
movie_rating=[]
for i in rating:
    movie_rating.append(i.text.replace("\n",""))
movie_rating
# Out:
# ['9.3',
#  '9.2',
#  '9.0',
#  '9.0',
#  '9.0',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.8',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.7',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5']

# %%
import pandas as pd
Imdb=pd.DataFrame({})
Imdb["movie_name"]=movie_name
Imdb["movie_year"]=movie_year
Imdb["movie_rating"]=movie_rating
Imdb
# Out:
#                                            movie_name movie_year movie_rating
# 0                    1.The Shawshank Redemption(1994)     (1994)          9.3
# 1                               2.The Godfather(1972)     (1972)          9.2
# 2                             3.The Dark Knight(2008)     (2008)          9.0
# 3                      4.The Godfather: Part II(1974)     (1974)          9.0
# 4                                5.12 Angry Men(1957)     (1957)          9.0
# 5   6.The Lord of the Rings: The Return of the Kin...     (2003)          8.9
# 6                                7.Pulp Fiction(1994)     (1994)          8.9
# 7                            8.Schindler's List(1993)     (1993)          8.9
# 8                                   9.Inception(2010)     (2010)          8.8
# 9                                 10.Fight Club(1999)     (1999)          8.8
# 10  11.The Lord of the Rings: The Fellowship of th...     (2001)          8.8
# ...

# %%
Imdb.to_csv("imdb.csv")
im=pd.read_csv("imdb.csv")
im.head()
# Out:
#    Unnamed: 0                        movie_name movie_year  movie_rating
# 0           0  1.The Shawshank Redemption(1994)     (1994)           9.3
# 1           1             2.The Godfather(1972)     (1972)           9.2
# 2           2           3.The Dark Knight(2008)     (2008)           9.0
# 3           3    4.The Godfather: Part II(1974)     (1974)           9.0
# 4           4              5.12 Angry Men(1957)     (1957)           9.0

# %%
##3. Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year of release) 
##and save it in form of a CSV file.
page=requests.get("https://www.imdb.com/list/ls009997493/")
page.content
soup=BeautifulSoup(page.content)
name=soup.find_all("h3",class_="lister-item-header")
name
# Out:
# [<h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">1.</span>
#  <a href="/title/tt0405508/">Rang De Basanti</a>
#  <span class="lister-item-year text-muted unbold">(2006)</span>
#  </h3>, <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">2.</span>
#  <a href="/title/tt1187043/">3 Idiots</a>
#  <span class="lister-item-year text-muted unbold">(2009)</span>
#  </h3>, <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">3.</span>
#  <a href="/title/tt0986264/">Taare Zameen Par</a>
#  <span class="lister-item-year text-muted unbold">(2007)</span>
#  </h3>, <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">4.</span>
#  <a href="/title/tt0292490/">Dil Chahta Hai</a>
#  <span class="lister-item-year text-muted unbold">(2001)</span>
#  </h3>, <h3 class="lister-item-header">
#  <span class="lister-item-index unbold text-primary">5.</span>
# ...

# %%
mov_name=[]
for i in name:
    mov_name.append(i.text.replace("\n",""))
mov_name
# Out:
# ['1.Rang De Basanti(2006)',
#  '2.3 Idiots(2009)',
#  '3.Taare Zameen Par(2007)',
#  '4.Dil Chahta Hai(2001)',
#  '5.Swades: We, the People(2004)',
#  '6.Lagaan: Once Upon a Time in India(2001)',
#  '7.Gangs of Wasseypur(2012)',
#  '8.Barfi!(2012)',
#  '9.Anand(1971)',
#  '10.Munna Bhai M.B.B.S.(2003)',
#  '11.A Wednesday(2008)',
#  '12.Andaz Apna Apna(1994)',
#  '13.Sholay(1975)',
#  '14.Bhaag Milkha Bhaag(2013)',
#  '15.Hera Pheri(2000)',
#  '16.Udaan(2010)',
#  '17.Kahaani(2012)',
#  '18.Black(2005)',
#  '19.Chak De! India(2007)',
#  '20.Khosla Ka Ghosla!(2006)',
#  '21.Jo Jeeta Wohi Sikandar(1992)',
#  '22.Zindagi Na Milegi Dobara(2011)',
#  '23.Paan Singh Tomar(2012)',
#  '24.Dilwale Dulhania Le Jayenge(1995)',
#  '25.Omkara(2006)',
#  '26.Lage Raho Munna Bhai(2006)',
#  '27.Iqbal(2005)',
#  '28.The Lunchbox(2013)',
#  '29.Black Friday(2004)',
#  '30.Company(2002)',
#  '31.Gol Maal(1979)',
#  '32.Dev.D(2009)',
#  '33.Jaane Bhi Do Yaaro(1983)',
#  '34.OMG: Oh My God!(2012)',
# ...

# %%
rating=soup.find_all("div",class_="ipl-rating-star small")
mov_rating=[]
for i in rating:
    mov_rating.append(i.text.replace("\n",""))
mov_rating
len(mov_rating)
# Out:
# 100

# %%
year=soup.find_all("span",class_="lister-item-year text-muted unbold")
year
mov_year=[]
for i in year:
    mov_year.append(i.text.replace("\n",""))
mov_year
# Out:
# ['(2006)',
#  '(2009)',
#  '(2007)',
#  '(2001)',
#  '(2004)',
#  '(2001)',
#  '(2012)',
#  '(2012)',
#  '(1971)',
#  '(2003)',
#  '(2008)',
#  '(1994)',
#  '(1975)',
#  '(2013)',
#  '(2000)',
#  '(2010)',
#  '(2012)',
#  '(2005)',
#  '(2007)',
#  '(2006)',
#  '(1992)',
#  '(2011)',
#  '(2012)',
#  '(1995)',
#  '(2006)',
#  '(2006)',
#  '(2005)',
#  '(2013)',
#  '(2004)',
#  '(2002)',
#  '(1979)',
#  '(2009)',
#  '(1983)',
#  '(2012)',
#  '(1960)',
#  '(2009)',
#  '(2006)',
#  '(2007)',
#  '(1957)',
#  '(2002)',
#  '(1983)',
#  '(1988)',
#  '(1998)',
#  '(2012)',
#  '(2004)',
#  '(1999)',
#  '(2003)',
#  '(2008)',
#  '(1999)',
#  '(2003)',
#  '(1982)',
#  '(2013)',
#  '(2012)',
#  '(1975)',
#  '(2007)',
#  '(2003)',
#  '(2003)',
#  '(2008)',
#  '(1978)',
#  '(1976)',
#  '(1965)',
#  '(2013)',
#  '(1975)',
#  '(2013)',
#  '(1968)',
#  '(2008)',
#  '(2004)',
#  '(2013)',
#  '(1951)',
#  '(1955)',
#  '(1998)',
#  '(1998)',
#  '(1989)',
#  '(2008)',
#  '(2000)',
#  '(2003)',
# ...

# %%
import pandas as pd
Imdb_hindi=pd.DataFrame({})
Imdb_hindi["movie_name"]=mov_name
Imdb_hindi["movie_year"]=mov_year
Imdb_hindi["movie_rating"]=mov_rating
Imdb_hindi
# Out:
#                                    movie_name  movie_year movie_rating
# 0                     1.Rang De Basanti(2006)      (2006)          8.1
# 1                            2.3 Idiots(2009)      (2009)          8.4
# 2                    3.Taare Zameen Par(2007)      (2007)          8.4
# 3                      4.Dil Chahta Hai(2001)      (2001)          8.1
# 4              5.Swades: We, the People(2004)      (2004)          8.2
# 5   6.Lagaan: Once Upon a Time in India(2001)      (2001)          8.1
# 6                  7.Gangs of Wasseypur(2012)      (2012)          8.2
# 7                              8.Barfi!(2012)      (2012)          8.1
# 8                               9.Anand(1971)      (1971)          8.3
# 9                10.Munna Bhai M.B.B.S.(2003)      (2003)          8.1
# 10                       11.A Wednesday(2008)      (2008)          8.1
# 11                   12.Andaz Apna Apna(1994)      (1994)          8.2
# ...

# %%
Imdb_hindi.to_csv("imdb_hindi.csv")
im_hindi=pd.read_csv("imdb_hindi.csv")
im_hindi.head()
# Out:
#    Unnamed: 0                      movie_name movie_year  movie_rating
# 0           0         1.Rang De Basanti(2006)     (2006)           8.1
# 1           1                2.3 Idiots(2009)     (2009)           8.4
# 2           2        3.Taare Zameen Par(2007)     (2007)           8.4
# 3           3          4.Dil Chahta Hai(2001)     (2001)           8.1
# 4           4  5.Swades: We, the People(2004)     (2004)           8.2

# %%
#4. Write a python program to scrap book name, author name, genre and book review of any 5 books from ‘www.bookpage.com’

# %%
page=requests.get("https://bookpage.com/reviews?book_genre=fiction&page=1")
soup=BeautifulSoup(page.content)
name=soup.find_all("h4",class_="italic")
book_name=[]
for i in name:
    book_name.append(i.text.replace("\n",""))
book_name[:5]
# Out:
# ['The Most Beautiful Girl in Cuba',
#  'The Last Thing He Told Me',
#  ' ★ Secrets of Happiness',
#  'Olympus, Texas',
#  ' ★ Sorrowland']

# %%
author=soup.find_all("p",class_="sans bold")
author_name=[]
for i in author:
    author_name.append(i.text.replace("\n",""))
author_name[:5]
# Out:
# ['Chanel Cleeton',
#  'Laura Dave',
#  'Joan Silber',
#  'Stacey Swann',
#  'Rivers Solomon']

# %%
genre=soup.find_all("p",class_="genre-links hidden-phone")
genre_name=[]
for i in genre:
    genre_name.append(i.text.replace("\n",""))
genre_name[:5]
# Out:
# ['Fiction / Historical Fiction',
#  'Fiction / Family Drama',
#  'Fiction / Family Drama',
#  'Fiction / Family Drama',
#  'Fiction / Gothic Fiction']

# %%
review=soup.find_all("p",class_="excerpt")
book_review=[]
for i in review:
    book_review.append(i.text.replace("\n",""))
book_review[:5]
# Out:
# ['Chanel Cleeton delivers a sweeping story of love and courage, as well as a sobering reminder of the power and responsibility of the media.',
#  'Laura Dave has given us what we crave right now—a thoroughly engrossing yet comforting distraction.',
#  'Rarely is a novel of moral ideas so buoyant in spirit or so exquisitely crafted.',
#  'A man’s return to his Texas hometown sets off a chain of events as tragic as any caused by the mythological gods.',
#  'Full of horror and love, Sorrowland is so perfectly plotted that readers can’t predict what’s to come any better than its characters can.']

# %%
bookpage=pd.DataFrame({})
bookpage["book_name"]=book_name[:5]
bookpage["author_name"]=author_name[:5]
bookpage["genre_name"]=genre_name[:5]
bookpage["book_review"]=book_review[:5]
bookpage
# Out:
#                          book_name     author_name  \
# 0  The Most Beautiful Girl in Cuba  Chanel Cleeton
# 1        The Last Thing He Told Me      Laura Dave
# 2           ★ Secrets of Happiness     Joan Silber
# 3                   Olympus, Texas    Stacey Swann
# 4                     ★ Sorrowland  Rivers Solomon
#
#                      genre_name  \
# 0  Fiction / Historical Fiction
# 1        Fiction / Family Drama
# 2        Fiction / Family Drama
# 3        Fiction / Family Drama
# 4      Fiction / Gothic Fiction
#
#                                          book_review
# 0  Chanel Cleeton delivers a sweeping story of lo...
# 1  Laura Dave has given us what we crave right no...
# 2  Rarely is a novel of moral ideas so buoyant in...
# 3  A man’s return to his Texas hometown sets off ...
# 4  Full of horror and love, Sorrowland is so perf...

# %%
#5. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:
#i) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
#ii) Top 10 ODI Batsmen in men along with the records of their team and rating.
#iii) Top 10 ODI bowlers along with the records of their team and rating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
soup=BeautifulSoup(page.content,'html.parser')
team=soup.find_all("span",class_="u-hide-phablet")
teamlist=[]
for i in team:
    teamlist.append(i.text.replace("\n",""))
teamlist[:10]
# Out:
# ['New Zealand',
#  'Australia',
#  'India',
#  'England',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan']

# %%
match=soup.find_all("td",class_="table-body__cell u-center-text")
matches=[]
for i in match:
    matches.append(i.text.replace("\n",""))
matches[:20]
# Out:
# ['25',
#  '2,945',
#  '29',
#  '3,344',
#  '27',
#  '3,100',
#  '20',
#  '2,137',
#  '24',
#  '2,323',
#  '24',
#  '2,157',
#  '27',
#  '2,222',
#  '21',
#  '1,652',
#  '17',
#  '1,054',
#  '2',
#  '99']

# %%
matchlist=[]
pointlist=[]
for i in range(len(matches)):
    if i%2==0:
        matchlist.append(matches[i])
    else:
        pointlist.append(matches[i])

# %%
matchlist
# Out:
# ['25',
#  '29',
#  '27',
#  '20',
#  '24',
#  '24',
#  '27',
#  '21',
#  '17',
#  '2',
#  '18',
#  '15',
#  '7',
#  '5',
#  '5',
#  '9',
#  '6',
#  '8',
#  '5']

# %%
matchlist.insert(0,"17")

# %%
pointlist
# Out:
# ['2,945',
#  '3,344',
#  '3,100',
#  '2,137',
#  '2,323',
#  '2,157',
#  '2,222',
#  '1,652',
#  '1,054',
#  '99',
#  '818',
#  '588',
#  '240',
#  '148',
#  '119',
#  '190',
#  '97',
#  '93',
#  '0']

# %%
pointlist.insert(0,"2054")

# %%
matchlist
# Out:
# ['17',
#  '25',
#  '29',
#  '27',
#  '20',
#  '24',
#  '24',
#  '27',
#  '21',
#  '17',
#  '2',
#  '18',
#  '15',
#  '7',
#  '5',
#  '5',
#  '9',
#  '6',
#  '8',
#  '5']

# %%
pointlist
# Out:
# ['2054',
#  '2,945',
#  '3,344',
#  '3,100',
#  '2,137',
#  '2,323',
#  '2,157',
#  '2,222',
#  '1,652',
#  '1,054',
#  '99',
#  '818',
#  '588',
#  '240',
#  '148',
#  '119',
#  '190',
#  '97',
#  '93',
#  '0']

# %%
rate=soup.find_all("td",class_="table-body__cell u-text-right rating")
rating=[]
for i in rate:
    rating.append(i.text.replace("\n",""))
rating[:10]
# Out:
# ['118', '115', '115', '107', '97', '90', '82', '79', '62', '50']

# %%
rating.insert(0,"121")
rating
# Out:
# ['121',
#  '118',
#  '115',
#  '115',
#  '107',
#  '97',
#  '90',
#  '82',
#  '79',
#  '62',
#  '50',
#  '45',
#  '39',
#  '34',
#  '30',
#  '24',
#  '21',
#  '16',
#  '12',
#  '0']

# %%
rating[:10]
# Out:
# ['121', '118', '115', '115', '107', '97', '90', '82', '79', '62']

# %%
topodi=pd.DataFrame({})
topodi["team"]=teamlist[:10]
topodi["matches"]=matchlist[:10]
topodi["points"]=pointlist[:10]
topodi["rating"]=rating[:10]
topodi
# Out:
#            team matches points rating
# 0   New Zealand      17   2054    121
# 1     Australia      25  2,945    118
# 2         India      29  3,344    115
# 3       England      27  3,100    115
# 4  South Africa      20  2,137    107
# 5      Pakistan      24  2,323     97
# 6    Bangladesh      24  2,157     90
# 7   West Indies      27  2,222     82
# 8     Sri Lanka      21  1,652     79
# 9   Afghanistan      17  1,054     62

# %%
#Top 10 ODI Batsmen in men along with the records of their team and rating.
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi")
page.content
soup=BeautifulSoup(page.content)
player=soup.find_all("td",class_="table-body__cell name")
playerlist=[]
for i in player:
    playerlist.append(i.text.replace("\n",""))
playerlist
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope',
#  'Mujeeb Ur Rahman',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Chris Woakes',
#  'Josh Hazlewood',
#  'Pat Cummins',
#  'Mohammad Amir',
#  'Ben Stokes',
#  'Mohammad Nabi',
#  'Chris Woakes',
#  'Rashid Khan',
#  'Mitchell Santner',
#  'Imad Wasim',
#  'Colin de Grandhomme',
#  'Ravindra Jadeja',
#  'Sean Williams',
#  'Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope',
#  'Mujeeb Ur Rahman',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Chris Woakes',
#  'Josh Hazlewood',
#  'Pat Cummins',
#  'Mohammad Amir',
#  'Ben Stokes',
#  'Mohammad Nabi',
#  'Chris Woakes',
#  'Rashid Khan',
#  'Mitchell Santner',
#  'Imad Wasim',
# ...

# %%
playerlist.insert(0,"Babar Azam")
playerlist[:10]
# Out:
# ['Babar Azam',
#  'Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope']

# %%
team=soup.find_all("span",class_="table-body__logo-text")
teamlist=[]
for i in team:
    teamlist.append(i.text.replace("\n",""))
teamlist
teamlist.insert(0,"PAK")

# %%
teamlist[:10]
# Out:
# ['PAK', 'IND', 'IND', 'NZ', 'AUS', 'ENG', 'PAK', 'SA', 'AUS', 'WI']

# %%
rate=soup.find_all("td",class_="table-body__cell u-text-right rating")
rating=[]
for i in rate:
    rating.append(i.text.replace("\n",""))
rating
rating.insert(0,"865")
rating[:10]
# Out:
# ['865', '857', '825', '801', '791', '785', '778', '778', '773', '773']

# %%
topbats=pd.DataFrame({})
topbats["player"]=playerlist[:10]
topbats["team"]=teamlist[:10]
topbats["rating"]=rating[:10]
topbats
# Out:
#                 player team rating
# 0           Babar Azam  PAK    865
# 1          Virat Kohli  IND    857
# 2         Rohit Sharma  IND    825
# 3          Ross Taylor   NZ    801
# 4          Aaron Finch  AUS    791
# 5       Jonny Bairstow  ENG    785
# 6         Fakhar Zaman  PAK    778
# 7  Francois du Plessis   SA    778
# 8         David Warner  AUS    773
# 9            Shai Hope   WI    773

# %%
#Top 10 ODI bowlers along with the records of their team and rating.
page=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")
soup=BeautifulSoup(page.content)
bowlerlist=soup.find_all("td",class_="table-body__cell rankings-table__name name")
bowler=[]
for i in bowlerlist:
    bowler.append(i.text.replace("\n",""))
bowler[:10]
# Out:
# ['Mujeeb Ur Rahman',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Chris Woakes',
#  'Josh Hazlewood',
#  'Pat Cummins',
#  'Mohammad Amir',
#  'Shaheen Afridi']

# %%
bowler.insert(0,"Trent Boult")
bowler[:10]
# Out:
# ['Trent Boult',
#  'Mujeeb Ur Rahman',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mehedi Hasan',
#  'Kagiso Rabada',
#  'Chris Woakes',
#  'Josh Hazlewood',
#  'Pat Cummins',
#  'Mohammad Amir']

# %%
teamlist=soup.find_all("span",class_="table-body__logo-text")
team=[]
for i in teamlist:
    team.append(i.text.replace("\n",""))
team[:10]
team.insert(0,"NZ")
team[:10]
# Out:
# ['NZ', 'AFG', 'NZ', 'IND', 'BAN', 'SA', 'ENG', 'AUS', 'AUS', 'PAK']

# %%
rate=soup.find_all("td",class_="table-body__cell rating")
rating=[]
for i in rate:
    rating.append(i.text.replace("\n",""))
rating[:10]
rating.insert(0,"737")
rating[:10]
# Out:
# ['737', '708', '691', '690', '668', '666', '665', '660', '646', '638']

# %%
odibowler=pd.DataFrame({})
odibowler["player"]=bowler[:10]
odibowler["team"]=team[:10]
odibowler["rating"]=rating[:10]
odibowler
# Out:
#              player team rating
# 0       Trent Boult   NZ    737
# 1  Mujeeb Ur Rahman  AFG    708
# 2        Matt Henry   NZ    691
# 3    Jasprit Bumrah  IND    690
# 4      Mehedi Hasan  BAN    668
# 5     Kagiso Rabada   SA    666
# 6      Chris Woakes  ENG    665
# 7    Josh Hazlewood  AUS    660
# 8       Pat Cummins  AUS    646
# 9     Mohammad Amir  PAK    638

# %%
#6. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:
#i) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
#ii) Top 10 women’s ODI players along with the records of their team and rating.
#iii) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
page.content
soup=BeautifulSoup(page.content)
teamlist=soup.find_all("span",class_="u-hide-phablet")
team=[]
for i in teamlist:
    team.append(i.text.replace("\n",""))
team[:10]
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland']

# %%
match=soup.find_all("td",class_="table-body__cell u-center-text")
matches=[]
for i in match:
    matches.append(i.text.replace("\n",""))
matches[:20]
# Out:
# ['24',
#  '2,828',
#  '17',
#  '1,993',
#  '20',
#  '2,226',
#  '21',
#  '1,947',
#  '12',
#  '1,025',
#  '15',
#  '1,101',
#  '5',
#  '306',
#  '11',
#  '519',
#  '2',
#  '25']

# %%
matchlist=[]
pointlist=[]
for i in range(len(matches)):
    if i%2==0:
        matchlist.append(matches[i])
    else:
        pointlist.append(matches[i])

# %%
matchlist.insert(0,"18")
pointlist.insert(0,"2955")

# %%
matchlist[:10]
# Out:
# ['18', '24', '17', '20', '21', '12', '15', '5', '11', '2']

# %%
pointlist[:10]
# Out:
# ['2955',
#  '2,828',
#  '1,993',
#  '2,226',
#  '1,947',
#  '1,025',
#  '1,101',
#  '306',
#  '519',
#  '25']

# %%
rate=soup.find_all("td",class_="table-body__cell u-text-right rating")
rating=[]
for i in rate:
    rating.append(i.text.replace("\n",""))
rating[:10]
rating.insert(0,"164")
rating[:10]
# Out:
# ['164', '118', '117', '111', '93', '85', '73', '61', '47', '13']

# %%
import pandas as pd
oditeam=pd.DataFrame({})
oditeam["team"]=team[:10]
oditeam["matches"]=matchlist[:10]
oditeam["points"]=pointlist[:10]
oditeam["rating"]=rating[:10]
oditeam
# Out:
#            team matches points rating
# 0     Australia      18   2955    164
# 1  South Africa      24  2,828    118
# 2       England      17  1,993    117
# 3         India      20  2,226    111
# 4   New Zealand      21  1,947     93
# 5   West Indies      12  1,025     85
# 6      Pakistan      15  1,101     73
# 7    Bangladesh       5    306     61
# 8     Sri Lanka      11    519     47
# 9       Ireland       2     25     13

# %%
#Top 10 women’s ODI players along with the records of their team and rating.
page=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting")

# %%
page.content
soup=BeautifulSoup(page.content)
playerlist=soup.find_all("td",class_="table-body__cell rankings-table__name name")
player=[]
for i in playerlist:
    player.append(i.text.replace("\n",""))
player[:10]
# Out:
# ['Lizelle Lee',
#  'Alyssa Healy',
#  'Stafanie Taylor',
#  'Meg Lanning',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Mithali Raj',
#  'Natalie Sciver',
#  'Laura Wolvaardt',
#  'Ellyse Perry']

# %%
player.insert(0,"Tammy Beaumont")
player[:10]
# Out:
# ['Tammy Beaumont',
#  'Lizelle Lee',
#  'Alyssa Healy',
#  'Stafanie Taylor',
#  'Meg Lanning',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Mithali Raj',
#  'Natalie Sciver',
#  'Laura Wolvaardt']

# %%
teamlist=soup.find_all("span",class_="table-body__logo-text")
team=[]
for i in teamlist:
    team.append(i.text.replace("\n",""))
team[:10]
team.insert(0,"ENG")
team[:10]
# Out:
# ['ENG', 'SA', 'AUS', 'WI', 'AUS', 'NZ', 'IND', 'IND', 'ENG', 'SA']

# %%
rate=soup.find_all("td",class_="table-body__cell rating")
rating=[]
for i in rate:
    rating.append(i.text.replace("\n",""))
rating[:10]
rating.insert(0,"765")
rating[:10]
# Out:
# ['765', '758', '756', '746', '723', '715', '710', '709', '685', '683']

# %%
odiplayer=pd.DataFrame({})
odiplayer["player"]=player[:10]
odiplayer["team"]=team[:10]
odiplayer["rating"]=rating[:10]
odiplayer
# Out:
#               player team rating
# 0     Tammy Beaumont  ENG    765
# 1        Lizelle Lee   SA    758
# 2       Alyssa Healy  AUS    756
# 3    Stafanie Taylor   WI    746
# 4        Meg Lanning  AUS    723
# 5  Amy Satterthwaite   NZ    715
# 6    Smriti Mandhana  IND    710
# 7        Mithali Raj  IND    709
# 8     Natalie Sciver  ENG    685
# 9    Laura Wolvaardt   SA    683

# %%
#Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")
soup=BeautifulSoup(page.content)
playerlist=soup.find_all("td",class_="table-body__cell rankings-table__name name")
player=[]
for i in playerlist:
    player.append(i.text.replace("\n",""))
player[:10]
player.insert(0,"Marizanee Kapp")
player[:10]
# Out:
# ['Marizanee Kapp',
#  'Ellyse Perry',
#  'Stafanie Taylor',
#  'Natalie Sciver',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Sophie Devine',
#  'Amelia Kerr']

# %%
teamlist=soup.find_all("span",class_="table-body__logo-text")
team=[]
for i in teamlist:
    team.append(i.text.replace("\n",""))
team[:10]
team.insert(0,"SA")
team[:10]
# Out:
# ['SA', 'AUS', 'WI', 'ENG', 'IND', 'AUS', 'AUS', 'SA', 'NZ', 'NZ']

# %%
rate=soup.find_all("td",class_="table-body__cell rating")
rating=[]
for i in rate:
    rating.append(i.text.replace("\n",""))
rating[:10]
rating.insert(0,"418")
rating[:10]
# Out:
# ['418', '418', '410', '349', '343', '307', '252', '243', '242', '236']

# %%
allrounder=pd.DataFrame({})
allrounder["player"]=player[:10]
allrounder["team"]=team[:10]
allrounder["rating"]=rating[:10]
allrounder
# Out:
#              player team rating
# 0    Marizanee Kapp   SA    418
# 1      Ellyse Perry  AUS    418
# 2   Stafanie Taylor   WI    410
# 3    Natalie Sciver  ENG    349
# 4     Deepti Sharma  IND    343
# 5     Jess Jonassen  AUS    307
# 6  Ashleigh Gardner  AUS    252
# 7  Dane van Niekerk   SA    243
# 8     Sophie Devine   NZ    242
# 9       Amelia Kerr   NZ    236

# %%
##7. Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. 
##The scraped data should include Product Name, Price, Image URL and Average Rating.
page=requests.get("https://www.amazon.in/s?i=electronics&bbn=1389401031&rh=n%3A976419031%2Cn%3A1389401031%2Cn%3A1389432031%2Cp_36%3A-2000000&dc&qid=1620566960&rnid=1389401031&ref=sr_nr_n_3")

# %%
page.content
soup=BeautifulSoup(page.content)
model=soup.find_all("span",class_="a-size-base-plus a-color-base a-text-normal")
modellist=[]
for i in model:
    modellist.append(i.text.replace("\n",""))
modellist
price=soup.find_all("span",class_="a-price-whole")

# %%
pricelist=[]
for i in price:
    pricelist.append(i.text.replace("\n",""))
pricelist
# Out:
# ['8,499',
#  '14,999',
#  '12,499',
#  '6,799',
#  '8,499',
#  '8,499',
#  '12,499',
#  '14,499',
#  '10,999',
#  '12,499',
#  '14,499',
#  '6,799',
#  '9,999',
#  '6,799',
#  '11,999',
#  '10,999',
#  '11,990',
#  '16,999',
#  '11,990',
#  '13,499',
#  '14,999',
#  '10,999',
#  '11,999',
#  '10,999']

# %%
rate=soup.find_all("a",class_="a-popover-trigger a-declarative")
#<i class="a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom"><span class="a-icon-alt">4.3 out of 5 stars</span></i>
rating=[]
for i in rate:
    rating.append(i.text.replace("\n",""))
rating
# Out:
# ['4.2 out of 5 stars',
#  '4.3 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.3 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.3 out of 5 stars',
#  '4.3 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.3 out of 5 stars']

# %%
len(rating)
len(pricelist)
len(modellist)
# Out:
# 24

# %%
import re
images = soup.find_all('img', {'src':re.compile('.jpg')})
imagelist=[]
for image in images:
    imagelist.append(image['src']+'\n')
imagelist
# Out:
# ['https://images-eu.ssl-images-amazon.com/images/G/31/IN-hq/2021/img/Mobile_Traffic_/XCM_Manual_1321458_1651511_IN_3781247_400x39_en_IN._CB655944656_.jpg\n',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71-Su4Wr0HL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71QY6JV6FhS._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/716nHhG9SWL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71OGzLCrjZS._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71Kmfs0T0BL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71yYaNztZ0L._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71SSmaLA7xS._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71IqJQM2stL._AC_UL320_.jpg\n',
# ...

# %%
len(imagelist)
# Out:
# 25

# %%
image=imagelist[1:25]
image
# Out:
# ['https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71-Su4Wr0HL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71QY6JV6FhS._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/716nHhG9SWL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71OGzLCrjZS._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71Kmfs0T0BL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71yYaNztZ0L._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71SSmaLA7xS._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71IqJQM2stL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71hEzQGO5qL._AC_UL320_.jpg\n',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UL320_.jpg\n',
# ...

# %%
import pandas as pd
mobiledata=pd.DataFrame({})
mobiledata["Model"]=modellist
mobiledata["Price"]=pricelist
mobiledata["Rating"]=rating
mobiledata["imageurl"]=image
mobiledata
# Out:
#                                                 Model   Price  \
# 0   Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 500...   8,499
# 1   Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...  14,999
# 2   Redmi Note 10 (Shadow Black, 4GB RAM, 64GB Sto...  12,499
# 3   Redmi 9A (Nature Green, 2GB Ram, 32GB Storage)...   6,799
# 4   Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) ...   8,499
# 5   Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage)...   8,499
# 6   Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Storage)  12,499
# 7   Redmi Note 10 (Aqua Green, 6GB RAM, 128GB Stor...  14,499
# 8   Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage...  10,999
# 9   Redmi Note 10 (Frost White, 4GB RAM, 64GB Stor...  12,499
# 10  Redmi Note 10 (Shadow Black, 6GB RAM, 128GB St...  14,499
# 11  Redmi 9A (Midnight Black, 2GB RAM, 32GB Storag...   6,799
# 12  Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Sto...   9,999
# 13  Redmi 9A (Sea Blue, 2GB Ram, 32GB Storage) | 2...   6,799
# ...

# %%
#8. Write a python program to extract information about the local weather from the National Weather Service website of USA, 
#https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day extended forecast display for the city
#The data should include period, short description, temperature and description.

# %%
page=requests.get("https://forecast.weather.gov/MapClick.php?textField1=37.78&textField2=-122.42#.YJgUuIfitPZ")
soup=BeautifulSoup(page.content)
periodlist=soup.find_all("p",class_="period-name")
period=[]
for i in periodlist:
    period.append(i.text.replace("\n",""))
period
# Out:
# ['Today',
#  'Tonight',
#  'Monday',
#  'MondayNight',
#  'Tuesday',
#  'TuesdayNight',
#  'Wednesday',
#  'WednesdayNight',
#  'Thursday']

# %%
shortdes=soup.find_all("p",class_="short-desc")
smalldes=[]
for i in shortdes:
    smalldes.append(i.text.replace("\n",""))
smalldes
# Out:
# ['Sunny',
#  'Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Partly Cloudy',
#  'Mostly Sunny']

# %%
templist=soup.find_all("p",class_=["temp temp-high","temp temp-low"])
temp=[]
for i in templist:
    temp.append(i.text.replace("\n",""))
temp
# Out:
# ['High: 71 °F⇓',
#  'Low: 52 °F',
#  'High: 77 °F',
#  'Low: 52 °F',
#  'High: 75 °F',
#  'Low: 51 °F',
#  'High: 69 °F',
#  'Low: 51 °F',
#  'High: 67 °F']

# %%
detailist=soup.find_all("div",class_="col-sm-10 forecast-text")
descrip=[]
for i in detailist:
    descrip.append(i.text.replace("\n",""))
descrip[:9]
# Out:
# ['Sunny, with a temperature falling to around 67 by 5pm. West wind 11 to 15 mph, with gusts as high as 20 mph. ',
#  'Clear, with a low around 52. West wind 6 to 14 mph, with gusts as high as 18 mph. ',
#  'Sunny, with a high near 77. Light west northwest wind becoming west 10 to 15 mph in the afternoon. Winds could gust as high as 20 mph. ',
#  'Mostly clear, with a low around 52. West wind 5 to 14 mph. ',
#  'Sunny, with a high near 75. Light west northwest wind becoming west 10 to 15 mph in the afternoon. Winds could gust as high as 20 mph. ',
#  'Mostly clear, with a low around 51.',
#  'Sunny, with a high near 69.',
#  'Partly cloudy, with a low around 51.',
#  'Mostly sunny, with a high near 67.']

# %%
weather=pd.DataFrame({})
weather["Period"]=period
weather["Short_description"]=smalldes
weather["Temperature"]=temp
weather["Description"]=descrip[:9]
weather
# Out:
#            Period Short_description   Temperature  \
# 0           Today             Sunny  High: 71 °F⇓
# 1         Tonight             Clear    Low: 52 °F
# 2          Monday             Sunny   High: 77 °F
# 3     MondayNight      Mostly Clear    Low: 52 °F
# 4         Tuesday             Sunny   High: 75 °F
# 5    TuesdayNight      Mostly Clear    Low: 51 °F
# 6       Wednesday             Sunny   High: 69 °F
# 7  WednesdayNight     Partly Cloudy    Low: 51 °F
# 8        Thursday      Mostly Sunny   High: 67 °F
#
#                                          Description
# 0  Sunny, with a temperature falling to around 67...
# 1  Clear, with a low around 52. West wind 6 to 14...
# 2  Sunny, with a high near 77. Light west northwe...
# 3  Mostly clear, with a low around 52. West wind ...
# 4  Sunny, with a high near 75. Light west northwe...
# 5                Mostly clear, with a low around 51.
# 6                        Sunny, with a high near 69.
# ...
